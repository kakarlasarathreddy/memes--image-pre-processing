# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
from PIL import ImageChops

# %%
font1 = ImageFont.truetype(r"C:\Users\HOME\Downloads\BebasNeue\BebasNeue\Commercial\TTF\BebasNeue-Bold.ttf",16)
font2 = ImageFont.truetype(r"C:\Users\HOME\Downloads\BebasNeue\BebasNeue\Commercial\TTF\BebasNeue-Book.ttf",15)
font3 = ImageFont.truetype(r"C:\Users\HOME\Downloads\BebasNeue\BebasNeue\Commercial\TTF\BebasNeue-Light.ttf",16)
font4 = ImageFont.truetype(r"C:\Users\HOME\Downloads\BebasNeue\BebasNeue\Commercial\TTF\BebasNeue-Regular.ttf",20)

# %%
new_img = Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\30b1gx.jpg")
plt.imshow(new_img)

# %%
new_img = Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\30b1gx.jpg")
font3 = ImageFont.truetype(r"C:\Users\HOME\Downloads\BebasNeue\BebasNeue\Commercial\TTF\BebasNeue-Light.ttf",20)
draw = ImageDraw.Draw(new_img)
draw.text((125,50), "*o t h e r  c o u r s e",font=font3, \
          fill=(0,0,0), stroke_width=1)
draw.text((125,175), "*data s c i e n c e",font=font3, \
          fill=(0,0,0), stroke_width=1)
plt.imshow(new_img)

# %%
plt.imshow(Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\memes-4.jpg"))

# %%
meme2= Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\memes-4.jpg")
font = ImageFont.truetype(r"C:\Users\HOME\Downloads\Crimson_Text\CrimsonText-Regular.ttf",10)
draw = ImageDraw.Draw(meme2)
draw.text((75,50), "*Me After Python",font=font3, \
          fill=(255,255,255), stroke_width=1)
draw.text((75,25), "         *Me After Numpy",font=font3, \
          fill=(255,255,255), stroke_width=1)
draw.text((25,160), "*Me After Pandas",font=font3, \
          fill=(255,255,255), stroke_width=1)
draw.text((125,112), "*Me After Stats",font=font3, \
          fill=(255,255,255), stroke_width=1)
plt.imshow(meme2)

# %%
plt.imshow(Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\brahmanandam-folded-hands-apologizing.jpg"))

# %%
meme2 = Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\brahmanandam-folded-hands-apologizing.jpg")
font3 = ImageFont.truetype(r"C:\Users\HOME\Downloads\Crimson_Text\CrimsonText-Regular.ttf",30)
draw = ImageDraw.Draw(meme2)
draw.text((610,100),"*Data: Messy. Data after cleaning: Classy.",font=font3, \
          fill=(255,255,255), stroke_width=1)
plt.imshow(meme2)

# %%
meme3 = Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\adhurs-Meme-templates-6.webp")
plt.imshow(meme3)

# %%
meme3 = Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\adhurs-Meme-templates-6.webp")
font3 = ImageFont.truetype(r"C:\Users\HOME\Downloads\Crimson_Text\CrimsonText-Regular.ttf",45)
draw = ImageDraw.Draw(meme3)
draw.text((500,100), "*Day1 stats",font=font3, \
          fill=(255,255,255), stroke_width=1)
draw.text((500,300), "*Day1 ML",font=font3, \
          fill=(255,255,255), stroke_width=1)
draw.text((500,500), "*Day1 DL",font=font3, \
          fill=(255,255,255), stroke_width=1)
plt.imshow(meme3)

# %%
plt.imshow(Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\images (2).jpg"))

# %%
new_img = Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\images (2).jpg")
font3 = ImageFont.truetype(r"C:\Users\HOME\Downloads\BebasNeue\BebasNeue\Commercial\TTF\BebasNeue-Light.ttf",15)
draw = ImageDraw.Draw(new_img)
draw.text((15,25), "*O u t l i e  r s: Data's w i l d s i d e.",font=font3, \
          fill=(0,255,0), stroke_width=1)
draw.text((15,175), "*D a t a's z e n m o d e.",font=font3, \
          fill=(128,0,0), stroke_width=1)
plt.imshow(new_img)

# %%
plt.imshow(Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\Am I a Joke To You 30102018153601.jpg"))

# %%
meme5 = Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\Am I a Joke To You 30102018153601.jpg")
font = ImageFont.truetype(r"C:\Users\HOME\Downloads\bell_mt\bell mt fett.ttf",15)
draw = ImageDraw.Draw(meme5)
draw.text((5,25),"*D a t a s h o w i n g   R a n g e o n  p o i n t !",font=font3, \
          fill=(0,255,0), stroke_width=1)
plt.imshow(meme5)

# %%
plt.imshow(Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\images (5).jpg"))

# %%
meme5 = Image.open(r"C:\Users\HOME\OneDrive\Desktop\New folder (2)\images (5).jpg")
font3 = ImageFont.truetype(r"C:\Users\HOME\Downloads\Crimson_Text\CrimsonText-Regular.ttf",15)
draw = ImageDraw.Draw(meme5)
draw.text((25,50), "*Me ",font=font3, \
          fill=(255,255,255))
draw = ImageDraw.Draw(meme5)
draw.text((5,150),"*AI-Elite-12: ML masters in training!",font=font3, \
          fill=(255,0,0), stroke_width=1)

# %%
plt.imshow(meme5)
